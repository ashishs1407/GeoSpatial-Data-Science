# %% [markdown]
# # <h1><center>Introduciton to Geopandas</center></h1>

# %% [markdown]
# In this section, we will learn the basics of loading and processing geographic data using Geopandas. Geopandas is built on top of Pandas and Numpy libraries. Like Pandas Dataframe, Geopandas data structure contains GeodataFrame and GeoSeries. Geopandas provides not only the capability to read and manipulate geographic data easily but also can perform many essential geospatial operations including among others geometric operations and projections which it borrows from the Shapely library.

# %% [markdown]
# ## 1 - Reading Spatial Data

# %% [markdown]
# ### Learning Objectives:
# 1. Read and write geographic data in Geopandas.

# %% [markdown]
# Vector Data comes in different formats (Shapefiles, Geopackage, Geojson ...etc). Luckily, Loading most of Geodata Formats with Geopandas is straightforward. We can use:
#
# ```
# read_file(pathname/file)
#
# ```

# %% [markdown]
# ###  .shp file format
# #### Shapefile - The shapefile format is a geospatial vector data format for geographic information system (GIS) software.

# %%
#!pip install geopandas

# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_geojson = gpd.read_file("data/acled2019_1-Geojson.geojson")
gdf_geojson.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty         event_date  year  \
# 0  6258850  275       PSE5105              5105      26 March 2019  2019
# 1  6045245  760      SYR53032             53032   19 February 2019  2019
# 2  6451367  887      YEM41046             41046       06 July 2019  2019
# 3  6070784  364       IRN5106              5106  06 September 2019  2019
# 4  5119428   12       ALG6175              6175      05 April 2019  2019
#
#    time_precision                  event_type  \
# 0               1  Explosions/Remote violence
# 1               1  Explosions/Remote violence
# 2               1  Explosions/Remote violence
# 3               1                    Protests
# 4               1                    Protests
#
#                       sub_event_type                             actor1  ...  \
# 0                   Air/drone strike  Military Forces of Israel (2009-)  ...
# 1  Shelling/artillery/missile attack   Military Forces of Syria (2000-)  ...
# 2  Shelling/artillery/missile attack         National Resistance Forces  ...
# 3                   Peaceful protest                  Protesters (Iran)  ...
# 4                   Peaceful protest               Protesters (Algeria)  ...
#
#   latitude  longitude geo_precision                              source  \
# 0  31.5000    34.4667             2                  Daily News (Egypt)
# 1  35.6469    36.3258             1                     SHAM; Liveuamap
# 2  13.4407    43.7034             2     Al Amaliqah; Yemen Data Project
# 3  37.5527    45.0761             1  Human Rights Activists News Agency
# 4  35.3758     1.3131             1                  El Watan (Algeria)
#
#               source_scale                                              notes  \
# 0            International  On March 26 2019, Israeli air strikes targeted...
# 1  Local partner-New media  Regime forces shelled the village of Kherbet E...
# 2   Local partner-National  On 6 July, anti-Houthi National Resistance For...
# 3                    Other  06 September 2019. Political prisoners at Orum...
# 4                 National  On 05 April, 2019, thousands of protesters gat...
#
#   fatalities   timestamp iso3                   geometry
# 0          0  1572403708  PSE  POINT (34.46670 31.50000)
# 1          0  1571164398  SYR  POINT (36.32580 35.64690)
# 2          6  1576530933  YEM  POINT (43.70340 13.44070)
# 3          0  1571164562  IRN  POINT (45.07610 37.55270)
# 4          0  1554749632  DZA   POINT (1.31310 35.37580)
#
# [5 rows x 32 columns]

# %%
gdf_geojson.shape
# Out:
# (1000, 32)

# %%
country = gpd.read_file("data/countries.shp")
country.head()
# Out:
#         NAME    POP_EST  GDP_MD_EST  POP_YEAR  LASTCENSUS  GDP_YEAR  \
# 0  Indonesia  260580739   3028000.0      2017        2010      2016
# 1   Malaysia   31381992    863000.0      2017        2010      2016
# 2      Chile   17789267    436100.0      2017        2002      2016
# 3    Bolivia   11138234     78350.0      2017        2001      2016
# 4       Peru   31036656    410400.0      2017        2007      2016
#
#                     ECONOMY              INCOME_GRP      CONTINENT REGION_UN  \
# 0  4. Emerging region: MIKT  4. Lower middle income           Asia      Asia
# 1      6. Developing region  3. Upper middle income           Asia      Asia
# 2   5. Emerging region: G20  3. Upper middle income  South America  Americas
# 3   5. Emerging region: G20  4. Lower middle income  South America  Americas
# 4   5. Emerging region: G20  3. Upper middle income  South America  Americas
#
#             SUBREGION                                           geometry
# 0  South-Eastern Asia  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  South-Eastern Asia  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2       South America  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3       South America  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4       South America  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...

# %% [markdown]
# # 2 - Let's Plot

# %%
import matplotlib.pyplot as plt

# %%
fig , ax = plt.subplots(1,1,figsize=(12,6))
                        
country.plot( ax=ax ,edgecolor='black',linewidth=.25,color="grey")
gdf_geojson.plot(ax=ax ,color="red",markersize = 1)
# Out:
# <AxesSubplot:>

# %%
gdf_geojson.plot(markersize = 5)
# Out:
# <AxesSubplot:>
